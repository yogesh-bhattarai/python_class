# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/python_class/blob/master/file_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file= open("/content/data.txt","r")

# %%
file
# Out:
# <_io.TextIOWrapper name='/content/data.txt' mode='r' encoding='utf-8'>

# %%
file= open("/content/data.txt","r")
content= file.read()
print(content)
file.close()
# Out:
# hello i am data scientist

# %%
file= open("/content/data.txt","a")
file.write("\ni am learning python")
file.close()

# %%
with open("/content/data.txt",'r') as f:
  content= f.read()
  print(content)
f.close()
# Out:
# hello i live in kathmandui am learning python
# i am learning python

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-179726827.py in <cell line: 0>()
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
try:
  x=10/0
except ZeroDivisionError:
  print("You cannot divide by zero")
# Out:
# You cannot divide by zero

# %%
try:
  x= int("abc")
except ValueError:
  print("Invalid value")
# Out:
# Invalid value

# %%
num= 0
if num==0:
  print("cannot divide")
else:
  print(10/num)
# Out:
# cannot divide

# %%
try:
  print(12/2)
except ZeroDivisionError:
  print("cannot divide by zero")
finally:
  print("This block of code run no matter what")
# Out:
# 6.0
# This block of code run no matter what

# %%
import pandas as pd
df= pd.read_excel(r"/content/titanic3.xlsx")

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
