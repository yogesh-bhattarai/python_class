# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/python_class/blob/master/pydantic_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydantic import BaseModel

# %%
class user(BaseModel):
  name:str
  age:int
user= user(name="yogesh",age="25")
type(user.age)
# Out:
# int
