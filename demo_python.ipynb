# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/pythonProject/blob/master/demo_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("python class")
# Out:
# python class

# %%
name="Ram"#string
age=20#interger
salary=200.60#float

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(salary)
# Out:
# float

# %%
x="5"
i=int(x)

# %%
print(x)
# Out:
# 5

# %%
type(x)
# Out:
# str

# %%
print(i)
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
name= input("Enter the name: ")
print("my name is",name)
# Out:
# Enter the name: bishal
# my name is bishal

# %%
age= int(input("Enter the age:"))
print("My age is",age)
# Out:
# Enter the age:20
# My age is 20

# %%
type(age)
# Out:
# int

# %%
num1= int(input("Enter first number:"))
num2= int(input("Enter second number:"))

sum= num1+num2
diff= num1-num2
mul= num1*num2
div=num1/num2

print("Sum:",sum)
print("Difference:",diff)
print("Multiply:",mul)
print("Division:",div)
# Out:
# Enter first number:10
# Enter second number:5
# Sum: 15
# Difference: 5
# Multiply: 50
# Division: 2.0
