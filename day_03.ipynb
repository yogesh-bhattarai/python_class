# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/python_class/blob/master/day_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age= int(input("Enter your age:"))
if age>=18:
  print("you are eligible for citizenship")
else:
  print("you are under age")
# Out:
# Enter your age:3
# you are under age

# %%
marks= int(input("Enter the marks:"))
if marks>=90:
  print("Grade A")
elif marks>=80:
  print("Grade B")
elif marks>=70:
  print("Grade C")
else:
  print("Grade D")
# Out:
# Enter the marks:92
# Grade A

# %%
age = int(input("Enter your age:"))
is_citizen= False
if age>=18:
  if is_citizen:
    print("you are eligible to vote")
  else:
    print("you are not eligible to vote")
else:
  print("you are not eligible to vote because you are underage")
# Out:
# Enter your age:15
# you are not eligible to vote because you are underage

# %%
# for loops concept

# %%
for i in range(1,7):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
fruits=['apple','banana','cherry']
for i in fruits:
  print(i)
# Out:
# apple
# banana
# cherry

# %%
fruits=['apple','banana','cherry']
for i in range(len(fruits)):
  print(fruits[i])
# Out:
# apple
# banana
# cherry

# %%
print(1+2+3+4+5)
# Out:
# 15

# %%
total=0
for i in range(1,6):
  total=total+i
print("Total:",total)
# Out:
# Total: 15

# %%
total=0
i=1
total=0+1
total=1
i=2
total=2+1
total=3
i=3
toal=9

# %%
#multiplication
a= int(input("Enter the number:"))
for i in range(1,11):
  result= i*a
  print(f"{a} * {i} = {result}")
# Out:
# Enter the number:3
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
i=1
while i<=5:#True
  print(i)
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
rows=5
for i in range(1,rows+1):
  print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
#loops with else block
numbers=[0,1,2,3,4,5]
for num in numbers:
  if num==0:
    print("Found 0")
    break
else:
  print("No zero found in this list")
# Out:
# Found 0

# %%
for i in range(1,11):
  if i==3:
    break
  print(i)
# Out:
# 1
# 2

# %%
for i in range(1,11):
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
for i in range(1,11):
  pass
