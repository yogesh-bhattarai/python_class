# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/python_class/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s= pd.Series([10,20,30],index=['a','b','c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
import pandas as pd
data={
    'Name': ["ram",'sita','Hari'],
    'Age': [25,22,30],
    'City': ["kathmandu",'chitwan','biratnagar']
}
df= pd.DataFrame(data)

# %%
df
# Out:
#    Name  Age        City
# 0   ram   25   kathmandu
# 1  sita   22     chitwan
# 2  Hari   30  biratnagar

# %%
df.iloc[0]
# Out:
# Name          ram
# Age            25
# City    kathmandu
# Name: 0, dtype: object

# %%
df[df['Age']>=25]
# Out:
#    Name  Age        City
# 0   ram   25   kathmandu
# 2  Hari   30  biratnagar

# %%
df= pd.read_excel(r"/content/titanic3.xlsx")

# %%
df.to_csv("titanic.csv",index=False)

# %%
df= pd.read_csv(r"/content/titanic.csv")

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.sample(10)
# Out:
#       pclass  survived                                               name  \
# 614        3         0                             Alexander, Mr. William
# 174        1         0                            Kent, Mr. Edward Austin
# 1068       3         0                          Nysveen, Mr. Johan Hansen
# 504        2         0                                  Meyer, Mr. August
# 382        2         0  Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...
# 882        3         0                              Jardin, Mr. Jose Neto
# 170        1         1                            Ismay, Mr. Joseph Bruce
# 687        3         0                       Braf, Miss. Elin Ester Maria
# 673        3         0                                Betros, Mr. Tannous
# 825        3         0                     Goodwin, Master. Harold Victor
#
#          sex   age  sibsp  parch              ticket     fare        cabin  \
# 614     male  26.0      0      0                3474   7.8875          NaN
# ...

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df['age'].fillna(df['age'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
df[df['sex']=='female']
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df[(df['sex']=='female') & (df['survived']==1)]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# ...      ...       ...                                                ...
# 1260       3         1                            Turja, Miss. Anna Sofia
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.727468
# male      0.190985
# Name: survived, dtype: float64

# %%
df.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.619195
# 2    0.429603
# 3    0.255289
# Name: survived, dtype: float64

# %%
df.sort_values(by='age',ascending=True)
# Out:
#       pclass  survived                                               name  \
# 763        3         1            Dean, Miss. Elizabeth Gladys "Millvina"
# 747        3         0            Danbom, Master. Gilbert Sigvard Emanuel
# 1240       3         1                    Thomas, Master. Assad Alexander
# 427        2         1                          Hamalainen, Master. Viljo
# 658        3         1                      Baclini, Miss. Helene Barbara
# ...      ...       ...                                                ...
# 9          1         0                            Artagaveytia, Mr. Ramon
# 135        1         0                          Goldschmidt, Mr. George B
# 1235       3         0                                Svensson, Mr. Johan
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
#
#          sex      age  sibsp  parch     ticket     fare cabin embarked boat  \
# ...

# %%
df['mul_age']= df['age'].apply(lambda x: x*10)

# %%
df.drop(columns=['mul_age'],inplace=True)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.groupby('sex')['age'].mean()
# Out:
# sex
# female    28.572067
# male      30.017892
# Name: age, dtype: float64
