# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/python_class/blob/master/Untitled56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list= [1,2,3,4]

# %%
type(my_list)
# Out:
# list

# %%
my_tuple=(1,2,3,4)

# %%
print(my_tuple)
# Out:
# (1, 2, 3, 4)

# %%
type(my_tuple)
# Out:
# tuple

# %%
person= ("aadarsha",24,"Nepal")
print(person)
# Out:
# ('aadarsha', 24, 'Nepal')

# %%
person[2]
# Out:
# 'Nepal'

# %%
my_tuple
# Out:
# (1, 2, 3, 4)

# %%
my_tuple[1]=20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4218734418.py in <cell line: 0>()
# ----> 1 my_tuple[1]=20
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list[1]= 24

# %%
my_list
# Out:
# [1, 24, 3, 4]

# %%
t=(5,)

# %%
type(t)
# Out:
# tuple

# %%
numbers=(10,20,30)
for n in numbers:
  print(n)
# Out:
# 10
# 20
# 30

# %%
a=(1,2,3)
a_list= list(a)
a_list.append(5)
t= tuple(a_list)
print(t)
# Out:
# (1, 2, 3, 5)

# %%
print(t)
# Out:
# (1, 2, 3, 5)

# %%
#sets

# %%
my_set={1,2,3,4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
numbers={1,2,2,3,3,3,4,4,5,5,5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
numbers.add(6)

# %%
numbers
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
numbers.remove(60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2863678214.py in <cell line: 0>()
# ----> 1 numbers.remove(60)
#
# KeyError: 60

# %%
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
numbers.discard(50)

# %%
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3,4}
print(2 in s)
# Out:
# True

# %%
print(6 in s)
# Out:
# False

# %%
nested_list=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

# %%
print(nested_list[2][2])
# Out:
# 9

# %%
#dictionary

# %%
student={
    "name": "Ram",
    "age": 23,
    "city": "Kathmandu"
}

# %%
print(student['city'])
# Out:
# Kathmandu

# %%
student['grade']= "A"
print(student)
# Out:
# {'name': 'Ram', 'age': 23, 'city': 'Kathmandu', 'grade': 'A'}

# %%
student['age']= 30

# %%
student
# Out:
# {'name': 'Ram', 'age': 30, 'city': 'Kathmandu', 'grade': 'A'}

# %%
students={
    "name": "Yogesh",
    "marks":{
        "math":90,
        "science":45
    }
}

# %%
print(students["marks"]['math'])
# Out:
# 90

# %%
students=[
    {"name":"Ram","age":23},
    {"name":"Shyam","age":24},
    {"name":"Hari","age":25},
]

# %%
print(students[1]['age'])
# Out:
# 24

# %%
dummy = [
    {
        "symbol": "BHL",
        "full_name": "Balephi Hydropower Limited",
        "sector": "HydroPower",
        "open": 178.0,
        "high": 180.7,
        "low": 178.0,
        "close": 178.0,
        "remaining_quantity": 2,
        "average_buy_price": 209.0,
        "total_buy_cost": 418.0,
        "current_value": 357.0,
        "profit_loss": -61.0,
        "profit_loss_percent": -14.59,
        "break_even_price": 209.0,
        "down_from_cost_percent": 14.59,
        "gain_needed_to_break_even_percent": 17.09,}]

# %%
dummy[0]['full_name']
# Out:
# 'Balephi Hydropower Limited'

# %%
sqaures= {x: x*x for x in range(1,6)}

# %%
print(sqaures)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
names=["Ram","Shyam","Hari"]
lenght= {name : len(name) for name in names}

# %%
print(lenght)
# Out:
# {'Ram': 3, 'Shyam': 5, 'Hari': 4}
