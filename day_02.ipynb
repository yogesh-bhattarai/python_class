# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/python_class/blob/master/day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=3

# %%
#arthemetic operator

# %%
#addition
print("a + b =", a+b)
# Out:
# a + b = 13

# %%
#substraction
print("a - b =", a-b)
# Out:
# a - b = 7

# %%
#multiplication
print("a * b =", a*b)
# Out:
# a * b = 30

# %%
#division
print("a / b =", a/b)
# Out:
# a / b = 3.3333333333333335

# %%
#modulus
print("a % b =", a%b)
# Out:
# a % b = 1

# %%
#power
print("a ** b =", a**b)
# Out:
# a ** b = 1000

# %%
print("a // b =", a//b)
# Out:
# a // b = 3

# %%
#comparision operator
a=10
b=10
#eqaul to
print("a==b:",a==b)
#not equal to
print("a!=b:",a!=b)
#greater than
print("a>b:",a>b)
#less than
print("a<b:",a<b)
#greater than and equal to
print("a>=b:",a>=b)
#smaller than and equal to
print("a<=b:",a<=b)
# Out:
# a==b: True
# a!=b: False
# a>b: False
# a<b: False
# a>=b: True
# a<=b: True

# %%
#logical operator
a=10
b=5
c=2

# %%
#and opeator
print(a>b and b>c)
# Out:
# True

# %%
print(a>b and b<c)
# Out:
# False

# %%
#or operator
print(a>b or b<c)
# Out:
# True

# %%
#not operator
print(not(a<b))
# Out:
# True

# %%
#membership operator
a=[1,2,3,4,5]
print(1 not in a)
# Out:
# False

# %%
#string
text= "programming"
print(text[0:6])
# Out:
# progra

# %%
print(text[:6])
# Out:
# progra

# %%
print(text[3:])
# Out:
# gramming

# %%
name="nischal"
age=50
print(f"My name is {name} and his age is {age} ")
# Out:
# My name is nischal and his age is 50

# %%
text= "Hello World"
print(text.upper())
# Out:
# HELLO WORLD

# %%
print(text.lower())
# Out:
# hello world

# %%
print(len(text))
# Out:
# 11

# %%
print(text.replace("World","Python"))
# Out:
# Hello Python

# %%
#list
fruits=["apple","banana","cherry"]
fruits.append("mango")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
fruits.insert(1,"orange")
print(fruits)
# Out:
# ['apple', 'orange', 'banana', 'cherry', 'mango']
